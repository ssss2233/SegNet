# %%
import torch
from torch import nn
import torch.nn.functional as f
import torchvision
import torchvision.transforms as tfs
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torchvision.models as models
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from datetime import datetime
import tqdm
from dataset import CamVidDataset
from utils import label_accuracy_score
from utils import get_weights
from utils import CrossEntropyLoss2d
# from segnet1 import SegNet
from segnet_dropout import SegNet
# from deeplabv3_plus import DeepLab
# from segnet import SegNet
# from segnet import SegResNet

# %%
# 数据集中对应的标签
classes = ["Animal", "Archway","Bicyclist","Bridge","Building","Car","CartLuggagePram",
          "Child","Column_Pole", "Fence", "LaneMkgsDriv", "LaneMkgsNonDriv", "Misc_Text",
          "MotorcycleScooter", "OtherMoving", "ParkingBlock", "Pedestrian", "Road", "RoadShoulder",
          "Sidewalk", "SignSymbol", "Sky", "SUVPickupTruck", "TrafficCone", "TrafficLight",
          "Train", "Tree", "Truck_Bus", "Tunnel", "VegetationMisc", "Void", "Wall"]

# 各种标签所对应的RGB值
colormap = [[64,128,64],[192,0,128],[0,128,192],[0,128,64],[128,0,0],[64,0,128],
           [64,0,192],[192,128,64],[192,192,128],[64,64,128],[128,0,192],[192,0,64],
           [128,128,64],[192,0,192],[128,64,64],[64,192,128],[64,64,0],[128,64,128],
           [128,128,192],[0,0,192],[192,128,128],[128,128,128],[64,128,192],[0,0,64],
           [0,64,64],[192,64,128],[128,128,0],[192,128,192],[64,0,64],[192,192,0],
           [0,0,0],[64,192,0]]

num_classes = len(classes)
print(num_classes)
print(len(colormap))
# Out:
# 32
# 32

# %%
size = 224
height = size
width = size
camvid_train = CamVidDataset(mode="train",add_val = False, augmentation = True)
camvid_test = CamVidDataset(mode="test")

train_data = DataLoader(camvid_train, batch_size=5, shuffle=True)
valid_data = DataLoader(camvid_test, batch_size=5)
print(len(train_data),len(camvid_train))
# Out:
# 274 1367

# %%
# 计算类权重
target = []
for image,label in camvid_train:
    target.append(label.numpy())
target = np.array(target)
target = torch.from_numpy(target)
weight = get_weights(target)

# %%
num_classes = len(classes)
# net = SegResNet(12)
net = SegNet(3,num_classes)
# net = SegNet(32)
if torch.cuda.is_available():
    net = net.cuda()
net.load_state_dict(torch.load(r"vgg16_bn-6c64b313.pth"),strict=False)
# criterion = nn.CrossEntropyLoss()
criterion = CrossEntropyLoss2d(weight = weight)
# 学习率不能太高，否则输出的标签就全变成0了
# LEARNING_RATE = 5e-6

# basic_optim = torch.optim.Adam(net.parameters(), lr=LEARNING_RATE, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)
# optimizer = basic_optim
# basic_optim = torch.optim.SGD(net.parameters(), lr=1e-2, weight_decay=1e-4)
basic_optim = torch.optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay=0)
optimizer = basic_optim
# scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer,milestones=[15,30,45], 
#                                                  gamma=0.1)

# %%
EPOCHES = 200

# 训练时的数据
train_loss = []
train_acc = []
train_acc_cls = []
train_mean_iu = []
train_fwavacc = []

# 验证时的数据
eval_loss = []
eval_acc = []
eval_acc_cls = []
eval_mean_iu = []
eval_fwavacc = []

# 记录在训练和测试集上预测出全零的图片数量
num_zero_train_epoch = 0
num_zero_test_epoch = 0
num_zero_train = 0
num_zero_test = 0
train_zero = []
test_zero = []


for e in (range(EPOCHES)):
    
    _train_loss = 0
    _train_acc = 0
    _train_acc_cls = 0
    _train_mean_iu = 0
    _train_fwavacc = 0
    
    prev_time = datetime.now()
    net = net.train()
    for img_data, img_label in (train_data):
        if torch.cuda.is_available:
            im = Variable(img_data).cuda()
            label = Variable(img_label).cuda()
        else:
            im = Variable(img_data)
            label = Variable(img_label)

        # 前向传播
        out = net(im)
        loss = criterion(out, label)

        # 反向传播
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        _train_loss += loss.item()
        
        label_pred = out.max(dim=1)[1].data.cpu().numpy()
        # 如果得到的所有像素点的分类都是0，则输出
        if(np.all(label_pred==0)):
            # print("train: all zero! epoch: "+str(e))
            num_zero_train_epoch += 1
        label_true = label.data.cpu().numpy()

        for lbt, lbp in zip(label_true, label_pred):
            acc, acc_cls, mean_iu, fwavacc = label_accuracy_score(lbt, lbp, num_classes)
            _train_acc += acc
            _train_acc_cls += acc_cls
            _train_mean_iu += mean_iu
            _train_fwavacc += fwavacc
#         scheduler.step()
    # print("epoch "+str(e)+" train : "+" num of zero label=" + str(num_zero_train_epoch))
    num_zero_train += num_zero_train_epoch
    train_zero.append(num_zero_train_epoch)
    num_zero_train_epoch = 0
    
    # 记录当前轮的数据
    train_loss.append(_train_loss/len(train_data))
    train_acc.append(_train_acc/len(camvid_train))
    train_acc_cls.append(_train_acc_cls)
    train_mean_iu.append(_train_mean_iu/len(camvid_train))
    train_fwavacc.append(_train_fwavacc)


    net = net.eval()
    
    _eval_loss = 0
    _eval_acc = 0
    _eval_acc_cls = 0
    _eval_mean_iu = 0
    _eval_fwavacc = 0
    
    for img_data, img_label in valid_data:
        if torch.cuda.is_available():
            im = Variable(img_data).cuda()
            label = Variable(img_label).cuda()
        else:
            im = Variable(img_data)
            label = Variable(img_label)
        
        # forward
        out = net(im)
        loss = criterion(out, label)
        _eval_loss += loss.item()
        
        label_pred = out.max(dim=1)[1].data.cpu().numpy()
        if(np.all(label_pred==0)):
            # print("test: all zero! epoch: "+str(e))
            num_zero_test_epoch += 1
        label_true = label.data.cpu().numpy()
        for lbt, lbp in zip(label_true, label_pred):
            acc, acc_cls, mean_iu, fwavacc = label_accuracy_score(lbt, lbp, num_classes)
            _eval_acc += acc
            _eval_acc_cls += acc_cls
            _eval_mean_iu += mean_iu
            _eval_fwavacc += fwavacc
            
    # print("epoch "+str(e)+" test : "+" num of zero label= " + str(num_zero_test_epoch))
    num_zero_test += num_zero_test_epoch
    test_zero.append(num_zero_test_epoch)
    num_zero_test_epoch = 0
    
    # 记录当前轮的数据
    eval_loss.append(_eval_loss/len(valid_data))
    eval_acc.append(_eval_acc/len(camvid_test))
    eval_acc_cls.append(_eval_acc_cls)
    eval_mean_iu.append(_eval_mean_iu/len(camvid_test))
    eval_fwavacc.append(_eval_fwavacc)

    # 打印当前轮训练的结果
    cur_time = datetime.now()
    h, remainder = divmod((cur_time - prev_time).seconds, 3600)
    m, s = divmod(remainder, 60)
    epoch_str = ('Epoch: {}, Train Loss: {:.5f}, Train Acc: {:.5f}, Train Mean IU: {:.5f}, \
Valid Loss: {:.5f}, Valid Acc: {:.5f},Valid Mean IU: {:.5f} ,'.format(
        e, _train_loss / len(train_data), _train_acc / len(camvid_train),_train_mean_iu / len(camvid_train),
        _eval_loss / len(valid_data), _eval_acc / len(camvid_test),_eval_mean_iu / len(camvid_test)))
    time_str = 'Time: {:.0f}:{:.0f}:{:.0f}'.format(h, m, s)
    print(epoch_str + time_str)
    # show()
# Out:
# /home/jovyan/segnet1/utils.py:55: RuntimeWarning: invalid value encountered in true_divide
#   acc_cls = np.diag(hist) / hist.sum(axis=1)
# /home/jovyan/segnet1/utils.py:58: RuntimeWarning: invalid value encountered in true_divide
#   iu = np.diag(hist) / (hist.sum(axis=1) + hist.sum(axis=0) - np.diag(hist))
# Epoch: 0, Train Loss: 2.97228, Train Acc: 0.13571, Train Mean IU: 0.03113, Valid Loss: 2.79619, Valid Acc: 0.10394,Valid Mean IU: 0.01893 ,Time: 0:1:11
# Epoch: 1, Train Loss: 2.68851, Train Acc: 0.18584, Train Mean IU: 0.04616, Valid Loss: 2.67868, Valid Acc: 0.13890,Valid Mean IU: 0.01895 ,Time: 0:0:35
# Epoch: 2, Train Loss: 2.58813, Train Acc: 0.25194, Train Mean IU: 0.05805, Valid Loss: 2.61170, Valid Acc: 0.15936,Valid Mean IU: 0.02239 ,Time: 0:0:35
# Epoch: 3, Train Loss: 2.49068, Train Acc: 0.33199, Train Mean IU: 0.07486, Valid Loss: 2.54838, Valid Acc: 0.26379,Valid Mean IU: 0.05616 ,Time: 0:0:35
# Epoch: 4, Train Loss: 2.36929, Train Acc: 0.37766, Train Mean IU: 0.08532, Valid Loss: 2.29990, Valid Acc: 0.32244,Valid Mean IU: 0.07178 ,Time: 0:0:36
# Epoch: 5, Train Loss: 2.27501, Train Acc: 0.42617, Train Mean IU: 0.09995, Valid Loss: 2.11556, Valid Acc: 0.37165,Valid Mean IU: 0.08569 ,Time: 0:0:35
# Epoch: 6, Train Loss: 2.17330, Train Acc: 0.43370, Train Mean IU: 0.10186, Valid Loss: 1.97318, Valid Acc: 0.38399,Valid Mean IU: 0.09448 ,Time: 0:0:35
# Epoch: 7, Train Loss: 2.09068, Train Acc: 0.44678, Train Mean IU: 0.10922, Valid Loss: 2.11595, Valid Acc: 0.38353,Valid Mean IU: 0.09904 ,Time: 0:0:35
# Epoch: 8, Train Loss: 2.04467, Train Acc: 0.46257, Train Mean IU: 0.11741, Valid Loss: 1.98612, Valid Acc: 0.42569,Valid Mean IU: 0.10702 ,Time: 0:0:36
# Epoch: 9, Train Loss: 2.03168, Train Acc: 0.46470, Train Mean IU: 0.11741, Valid Loss: 2.05390, Valid Acc: 0.40325,Valid Mean IU: 0.10178 ,Time: 0:0:35
# Epoch: 10, Train Loss: 1.97252, Train Acc: 0.47578, Train Mean IU: 0.12419, Valid Loss: 1.89916, Valid Acc: 0.42041,Valid Mean IU: 0.11047 ,Time: 0:0:35
# Epoch: 11, Train Loss: 1.95974, Train Acc: 0.48269, Train Mean IU: 0.12741, Valid Loss: 1.97461, Valid Acc: 0.41029,Valid Mean IU: 0.10812 ,Time: 0:0:35
# Epoch: 12, Train Loss: 1.92662, Train Acc: 0.49046, Train Mean IU: 0.13135, Valid Loss: 2.01027, Valid Acc: 0.42562,Valid Mean IU: 0.11353 ,Time: 0:0:35
# Epoch: 13, Train Loss: 1.88568, Train Acc: 0.50608, Train Mean IU: 0.13723, Valid Loss: 1.83673, Valid Acc: 0.43100,Valid Mean IU: 0.12146 ,Time: 0:0:35
# Epoch: 14, Train Loss: 1.88433, Train Acc: 0.50251, Train Mean IU: 0.13518, Valid Loss: 1.82196, Valid Acc: 0.44440,Valid Mean IU: 0.12573 ,Time: 0:0:34
# Epoch: 15, Train Loss: 1.87332, Train Acc: 0.50473, Train Mean IU: 0.13811, Valid Loss: 1.81135, Valid Acc: 0.44435,Valid Mean IU: 0.12823 ,Time: 0:0:36
# Epoch: 16, Train Loss: 1.85025, Train Acc: 0.51289, Train Mean IU: 0.14133, Valid Loss: 1.77476, Valid Acc: 0.46576,Valid Mean IU: 0.13542 ,Time: 0:0:34
# Epoch: 17, Train Loss: 1.79943, Train Acc: 0.52101, Train Mean IU: 0.14561, Valid Loss: 1.79507, Valid Acc: 0.46370,Valid Mean IU: 0.13839 ,Time: 0:0:35
# Epoch: 18, Train Loss: 1.77890, Train Acc: 0.52224, Train Mean IU: 0.14707, Valid Loss: 1.78550, Valid Acc: 0.46017,Valid Mean IU: 0.13554 ,Time: 0:0:35
# Epoch: 19, Train Loss: 1.76619, Train Acc: 0.53175, Train Mean IU: 0.14965, Valid Loss: 1.72382, Valid Acc: 0.51272,Valid Mean IU: 0.14975 ,Time: 0:0:36
# Epoch: 20, Train Loss: 1.73913, Train Acc: 0.54292, Train Mean IU: 0.15460, Valid Loss: 1.90863, Valid Acc: 0.43240,Valid Mean IU: 0.12865 ,Time: 0:0:35
# Epoch: 21, Train Loss: 1.71457, Train Acc: 0.54803, Train Mean IU: 0.15700, Valid Loss: 1.71915, Valid Acc: 0.50356,Valid Mean IU: 0.14501 ,Time: 0:0:36
# Epoch: 22, Train Loss: 1.68903, Train Acc: 0.56306, Train Mean IU: 0.16247, Valid Loss: 1.68403, Valid Acc: 0.49713,Valid Mean IU: 0.15383 ,Time: 0:0:36
# Epoch: 23, Train Loss: 1.66650, Train Acc: 0.56519, Train Mean IU: 0.16510, Valid Loss: 1.78353, Valid Acc: 0.46670,Valid Mean IU: 0.14048 ,Time: 0:0:36
# Epoch: 24, Train Loss: 1.65355, Train Acc: 0.56834, Train Mean IU: 0.16652, Valid Loss: 1.92164, Valid Acc: 0.44562,Valid Mean IU: 0.13700 ,Time: 0:0:35
# Epoch: 25, Train Loss: 1.64314, Train Acc: 0.57830, Train Mean IU: 0.16780, Valid Loss: 1.61880, Valid Acc: 0.51594,Valid Mean IU: 0.15983 ,Time: 0:0:36
# Epoch: 26, Train Loss: 1.62481, Train Acc: 0.58458, Train Mean IU: 0.17160, Valid Loss: 1.62220, Valid Acc: 0.51570,Valid Mean IU: 0.16874 ,Time: 0:0:35
# Epoch: 27, Train Loss: 1.59124, Train Acc: 0.58693, Train Mean IU: 0.17166, Valid Loss: 2.08998, Valid Acc: 0.45090,Valid Mean IU: 0.13278 ,Time: 0:0:35
# Epoch: 28, Train Loss: 1.60220, Train Acc: 0.59589, Train Mean IU: 0.17398, Valid Loss: 1.67326, Valid Acc: 0.51025,Valid Mean IU: 0.16063 ,Time: 0:0:34
# Epoch: 29, Train Loss: 1.57896, Train Acc: 0.59657, Train Mean IU: 0.16952, Valid Loss: 1.76667, Valid Acc: 0.45898,Valid Mean IU: 0.13456 ,Time: 0:0:35
# Epoch: 30, Train Loss: 1.54517, Train Acc: 0.61323, Train Mean IU: 0.17811, Valid Loss: 1.58766, Valid Acc: 0.54322,Valid Mean IU: 0.16569 ,Time: 0:0:35
# Epoch: 31, Train Loss: 1.53863, Train Acc: 0.61774, Train Mean IU: 0.18024, Valid Loss: 1.60123, Valid Acc: 0.52595,Valid Mean IU: 0.16312 ,Time: 0:0:34
# Epoch: 32, Train Loss: 1.52514, Train Acc: 0.62238, Train Mean IU: 0.18088, Valid Loss: 1.51349, Valid Acc: 0.60139,Valid Mean IU: 0.18962 ,Time: 0:0:35
# Epoch: 33, Train Loss: 1.51056, Train Acc: 0.63154, Train Mean IU: 0.18547, Valid Loss: 1.59529, Valid Acc: 0.58949,Valid Mean IU: 0.18272 ,Time: 0:0:35
# Epoch: 34, Train Loss: 1.49135, Train Acc: 0.63322, Train Mean IU: 0.18828, Valid Loss: 1.77161, Valid Acc: 0.53628,Valid Mean IU: 0.16330 ,Time: 0:0:34
# Epoch: 35, Train Loss: 1.46152, Train Acc: 0.64078, Train Mean IU: 0.18944, Valid Loss: 1.43671, Valid Acc: 0.58439,Valid Mean IU: 0.19117 ,Time: 0:0:34
# Epoch: 36, Train Loss: 1.45183, Train Acc: 0.64322, Train Mean IU: 0.19269, Valid Loss: 1.63780, Valid Acc: 0.57339,Valid Mean IU: 0.18342 ,Time: 0:0:35
# Epoch: 37, Train Loss: 1.42268, Train Acc: 0.65342, Train Mean IU: 0.19904, Valid Loss: 1.62836, Valid Acc: 0.57783,Valid Mean IU: 0.18281 ,Time: 0:0:35
# Epoch: 38, Train Loss: 1.43175, Train Acc: 0.65012, Train Mean IU: 0.19652, Valid Loss: 1.55083, Valid Acc: 0.57764,Valid Mean IU: 0.19510 ,Time: 0:0:35
# Epoch: 39, Train Loss: 1.44891, Train Acc: 0.64663, Train Mean IU: 0.19778, Valid Loss: 2.03015, Valid Acc: 0.40539,Valid Mean IU: 0.12240 ,Time: 0:0:35
# Epoch: 40, Train Loss: 1.46771, Train Acc: 0.64524, Train Mean IU: 0.19133, Valid Loss: 1.59356, Valid Acc: 0.60124,Valid Mean IU: 0.18872 ,Time: 0:0:34
# Epoch: 41, Train Loss: 1.40076, Train Acc: 0.66464, Train Mean IU: 0.20042, Valid Loss: 1.42493, Valid Acc: 0.63450,Valid Mean IU: 0.20172 ,Time: 0:0:36
# Epoch: 42, Train Loss: 1.38452, Train Acc: 0.67040, Train Mean IU: 0.20510, Valid Loss: 1.49911, Valid Acc: 0.63421,Valid Mean IU: 0.20295 ,Time: 0:0:36
# Epoch: 43, Train Loss: 1.37530, Train Acc: 0.67271, Train Mean IU: 0.20637, Valid Loss: 1.48697, Valid Acc: 0.62246,Valid Mean IU: 0.20761 ,Time: 0:0:35
# Epoch: 44, Train Loss: 1.35031, Train Acc: 0.68000, Train Mean IU: 0.20911, Valid Loss: 1.44894, Valid Acc: 0.58302,Valid Mean IU: 0.20424 ,Time: 0:0:34
# Epoch: 45, Train Loss: 1.34843, Train Acc: 0.67965, Train Mean IU: 0.21110, Valid Loss: 1.43254, Valid Acc: 0.61303,Valid Mean IU: 0.20532 ,Time: 0:0:35
# Epoch: 46, Train Loss: 1.33191, Train Acc: 0.69014, Train Mean IU: 0.21515, Valid Loss: 1.39496, Valid Acc: 0.62420,Valid Mean IU: 0.20456 ,Time: 0:0:34
# Epoch: 47, Train Loss: 1.31871, Train Acc: 0.68654, Train Mean IU: 0.21511, Valid Loss: 1.45498, Valid Acc: 0.64375,Valid Mean IU: 0.20714 ,Time: 0:0:35
# Epoch: 48, Train Loss: 1.31405, Train Acc: 0.69116, Train Mean IU: 0.21601, Valid Loss: 1.40856, Valid Acc: 0.64644,Valid Mean IU: 0.21077 ,Time: 0:0:36
# Epoch: 49, Train Loss: 1.29172, Train Acc: 0.69743, Train Mean IU: 0.21814, Valid Loss: 1.34809, Valid Acc: 0.64863,Valid Mean IU: 0.21283 ,Time: 0:0:35
# Epoch: 50, Train Loss: 1.28067, Train Acc: 0.69966, Train Mean IU: 0.21992, Valid Loss: 1.37112, Valid Acc: 0.66099,Valid Mean IU: 0.21418 ,Time: 0:0:36
# Epoch: 51, Train Loss: 1.25928, Train Acc: 0.70625, Train Mean IU: 0.22273, Valid Loss: 1.38061, Valid Acc: 0.62465,Valid Mean IU: 0.21046 ,Time: 0:0:34
# Epoch: 52, Train Loss: 1.24533, Train Acc: 0.70967, Train Mean IU: 0.22450, Valid Loss: 1.36808, Valid Acc: 0.66488,Valid Mean IU: 0.21458 ,Time: 0:0:35
# Epoch: 53, Train Loss: 1.24281, Train Acc: 0.71025, Train Mean IU: 0.22560, Valid Loss: 1.36007, Valid Acc: 0.66206,Valid Mean IU: 0.22859 ,Time: 0:0:34
# Epoch: 54, Train Loss: 1.25053, Train Acc: 0.70932, Train Mean IU: 0.22497, Valid Loss: 1.38990, Valid Acc: 0.64070,Valid Mean IU: 0.22085 ,Time: 0:0:35
# Epoch: 55, Train Loss: 1.24462, Train Acc: 0.70590, Train Mean IU: 0.22535, Valid Loss: 1.49805, Valid Acc: 0.63007,Valid Mean IU: 0.21491 ,Time: 0:0:35
# Epoch: 56, Train Loss: 1.22533, Train Acc: 0.71746, Train Mean IU: 0.23204, Valid Loss: 1.38475, Valid Acc: 0.66401,Valid Mean IU: 0.22521 ,Time: 0:0:34
# Epoch: 57, Train Loss: 1.21005, Train Acc: 0.71903, Train Mean IU: 0.23389, Valid Loss: 1.36176, Valid Acc: 0.64094,Valid Mean IU: 0.21943 ,Time: 0:0:35
# Epoch: 58, Train Loss: 1.18877, Train Acc: 0.72573, Train Mean IU: 0.23792, Valid Loss: 1.34647, Valid Acc: 0.67226,Valid Mean IU: 0.23033 ,Time: 0:0:35
# Epoch: 59, Train Loss: 1.17512, Train Acc: 0.72911, Train Mean IU: 0.24009, Valid Loss: 1.39558, Valid Acc: 0.65175,Valid Mean IU: 0.22248 ,Time: 0:0:35
# Epoch: 60, Train Loss: 1.16848, Train Acc: 0.72783, Train Mean IU: 0.24037, Valid Loss: 1.38697, Valid Acc: 0.66678,Valid Mean IU: 0.22386 ,Time: 0:0:35
# Epoch: 61, Train Loss: 1.16743, Train Acc: 0.73109, Train Mean IU: 0.23823, Valid Loss: 1.33098, Valid Acc: 0.67872,Valid Mean IU: 0.23175 ,Time: 0:0:34
# Epoch: 62, Train Loss: 1.15580, Train Acc: 0.73195, Train Mean IU: 0.23801, Valid Loss: 1.49355, Valid Acc: 0.66339,Valid Mean IU: 0.22383 ,Time: 0:0:35
# Epoch: 63, Train Loss: 1.14776, Train Acc: 0.73448, Train Mean IU: 0.24068, Valid Loss: 1.36518, Valid Acc: 0.65893,Valid Mean IU: 0.22343 ,Time: 0:0:37
# Epoch: 64, Train Loss: 1.13873, Train Acc: 0.73829, Train Mean IU: 0.24341, Valid Loss: 1.30241, Valid Acc: 0.67670,Valid Mean IU: 0.23970 ,Time: 0:0:35
# Epoch: 65, Train Loss: 1.13687, Train Acc: 0.73749, Train Mean IU: 0.24444, Valid Loss: 1.30493, Valid Acc: 0.66449,Valid Mean IU: 0.22949 ,Time: 0:0:35
# Epoch: 66, Train Loss: 1.13704, Train Acc: 0.73919, Train Mean IU: 0.24306, Valid Loss: 1.27215, Valid Acc: 0.67798,Valid Mean IU: 0.23770 ,Time: 0:0:35
# Epoch: 67, Train Loss: 1.12304, Train Acc: 0.74180, Train Mean IU: 0.24675, Valid Loss: 1.34538, Valid Acc: 0.67434,Valid Mean IU: 0.22819 ,Time: 0:0:35
# Epoch: 68, Train Loss: 1.11902, Train Acc: 0.74331, Train Mean IU: 0.24823, Valid Loss: 1.27497, Valid Acc: 0.67307,Valid Mean IU: 0.24750 ,Time: 0:0:35
# Epoch: 69, Train Loss: 1.11698, Train Acc: 0.74062, Train Mean IU: 0.24863, Valid Loss: 1.31021, Valid Acc: 0.67495,Valid Mean IU: 0.24066 ,Time: 0:0:36
# Epoch: 70, Train Loss: 1.11876, Train Acc: 0.74530, Train Mean IU: 0.25070, Valid Loss: 1.32134, Valid Acc: 0.69637,Valid Mean IU: 0.24352 ,Time: 0:0:35
# Epoch: 71, Train Loss: 1.10537, Train Acc: 0.74537, Train Mean IU: 0.24838, Valid Loss: 1.35776, Valid Acc: 0.67191,Valid Mean IU: 0.23050 ,Time: 0:0:36
# Epoch: 72, Train Loss: 1.09522, Train Acc: 0.75163, Train Mean IU: 0.25187, Valid Loss: 1.32821, Valid Acc: 0.67614,Valid Mean IU: 0.24400 ,Time: 0:0:34
# Epoch: 73, Train Loss: 1.08723, Train Acc: 0.75175, Train Mean IU: 0.25345, Valid Loss: 1.29658, Valid Acc: 0.65328,Valid Mean IU: 0.23828 ,Time: 0:0:35
# Epoch: 74, Train Loss: 1.08151, Train Acc: 0.75131, Train Mean IU: 0.25397, Valid Loss: 1.32135, Valid Acc: 0.68100,Valid Mean IU: 0.24267 ,Time: 0:0:34
# Epoch: 75, Train Loss: 1.06786, Train Acc: 0.75755, Train Mean IU: 0.25730, Valid Loss: 1.47298, Valid Acc: 0.64572,Valid Mean IU: 0.23183 ,Time: 0:0:36
# Epoch: 76, Train Loss: 1.05710, Train Acc: 0.75853, Train Mean IU: 0.25992, Valid Loss: 1.32620, Valid Acc: 0.69269,Valid Mean IU: 0.24717 ,Time: 0:0:36
# Epoch: 77, Train Loss: 1.05384, Train Acc: 0.75877, Train Mean IU: 0.26098, Valid Loss: 1.30033, Valid Acc: 0.68678,Valid Mean IU: 0.24430 ,Time: 0:0:35
# Epoch: 78, Train Loss: 1.05121, Train Acc: 0.75892, Train Mean IU: 0.26131, Valid Loss: 1.33115, Valid Acc: 0.68987,Valid Mean IU: 0.24942 ,Time: 0:0:35
# Epoch: 79, Train Loss: 1.05155, Train Acc: 0.75964, Train Mean IU: 0.25803, Valid Loss: 1.33108, Valid Acc: 0.68124,Valid Mean IU: 0.24488 ,Time: 0:0:36
# Epoch: 80, Train Loss: 1.04948, Train Acc: 0.75989, Train Mean IU: 0.25467, Valid Loss: 1.29326, Valid Acc: 0.69233,Valid Mean IU: 0.23099 ,Time: 0:0:35
# Epoch: 81, Train Loss: 1.05155, Train Acc: 0.76152, Train Mean IU: 0.25170, Valid Loss: 1.39059, Valid Acc: 0.66808,Valid Mean IU: 0.23196 ,Time: 0:0:35
# Epoch: 82, Train Loss: 1.03587, Train Acc: 0.76264, Train Mean IU: 0.25656, Valid Loss: 1.43323, Valid Acc: 0.64155,Valid Mean IU: 0.22374 ,Time: 0:0:34
# Epoch: 83, Train Loss: 1.03072, Train Acc: 0.76442, Train Mean IU: 0.26135, Valid Loss: 1.30027, Valid Acc: 0.69685,Valid Mean IU: 0.24509 ,Time: 0:0:35
# Epoch: 84, Train Loss: 1.02478, Train Acc: 0.76745, Train Mean IU: 0.26419, Valid Loss: 1.39724, Valid Acc: 0.64197,Valid Mean IU: 0.23555 ,Time: 0:0:35
# Epoch: 85, Train Loss: 1.02288, Train Acc: 0.76582, Train Mean IU: 0.26471, Valid Loss: 1.38149, Valid Acc: 0.66251,Valid Mean IU: 0.25276 ,Time: 0:0:34
# Epoch: 86, Train Loss: 1.00511, Train Acc: 0.76915, Train Mean IU: 0.26905, Valid Loss: 1.27477, Valid Acc: 0.69296,Valid Mean IU: 0.26435 ,Time: 0:0:35
# Epoch: 87, Train Loss: 1.01391, Train Acc: 0.76750, Train Mean IU: 0.26540, Valid Loss: 1.29539, Valid Acc: 0.67929,Valid Mean IU: 0.25323 ,Time: 0:0:35
# Epoch: 88, Train Loss: 0.99917, Train Acc: 0.77082, Train Mean IU: 0.26652, Valid Loss: 1.33635, Valid Acc: 0.69275,Valid Mean IU: 0.25115 ,Time: 0:0:36
# Epoch: 89, Train Loss: 0.99644, Train Acc: 0.77163, Train Mean IU: 0.26928, Valid Loss: 1.29313, Valid Acc: 0.69724,Valid Mean IU: 0.25922 ,Time: 0:0:35
# Epoch: 90, Train Loss: 0.98249, Train Acc: 0.77317, Train Mean IU: 0.27269, Valid Loss: 1.28692, Valid Acc: 0.67369,Valid Mean IU: 0.25230 ,Time: 0:0:35
# Epoch: 91, Train Loss: 0.98428, Train Acc: 0.77437, Train Mean IU: 0.27581, Valid Loss: 1.35480, Valid Acc: 0.67467,Valid Mean IU: 0.25095 ,Time: 0:0:35
# Epoch: 92, Train Loss: 0.98502, Train Acc: 0.77309, Train Mean IU: 0.27550, Valid Loss: 1.37130, Valid Acc: 0.65648,Valid Mean IU: 0.24209 ,Time: 0:0:34
# Epoch: 93, Train Loss: 0.98128, Train Acc: 0.77411, Train Mean IU: 0.27495, Valid Loss: 1.36507, Valid Acc: 0.67911,Valid Mean IU: 0.25035 ,Time: 0:0:35
# Epoch: 94, Train Loss: 0.98279, Train Acc: 0.77384, Train Mean IU: 0.27526, Valid Loss: 1.30872, Valid Acc: 0.63942,Valid Mean IU: 0.24383 ,Time: 0:0:35
# Epoch: 95, Train Loss: 0.98037, Train Acc: 0.77460, Train Mean IU: 0.27648, Valid Loss: 1.34336, Valid Acc: 0.66218,Valid Mean IU: 0.23977 ,Time: 0:0:34
# Epoch: 96, Train Loss: 0.96285, Train Acc: 0.77926, Train Mean IU: 0.27967, Valid Loss: 1.34642, Valid Acc: 0.68015,Valid Mean IU: 0.25080 ,Time: 0:0:35
# Epoch: 97, Train Loss: 0.96627, Train Acc: 0.77895, Train Mean IU: 0.27928, Valid Loss: 1.32386, Valid Acc: 0.70757,Valid Mean IU: 0.26497 ,Time: 0:0:35
# Epoch: 98, Train Loss: 0.95703, Train Acc: 0.77790, Train Mean IU: 0.28053, Valid Loss: 1.39168, Valid Acc: 0.66388,Valid Mean IU: 0.24526 ,Time: 0:0:36
# Epoch: 99, Train Loss: 0.95903, Train Acc: 0.77953, Train Mean IU: 0.28212, Valid Loss: 1.29757, Valid Acc: 0.70377,Valid Mean IU: 0.26267 ,Time: 0:0:35
# Epoch: 100, Train Loss: 0.95187, Train Acc: 0.78123, Train Mean IU: 0.28189, Valid Loss: 1.37247, Valid Acc: 0.67364,Valid Mean IU: 0.24887 ,Time: 0:0:35
# Epoch: 101, Train Loss: 0.94881, Train Acc: 0.78194, Train Mean IU: 0.28421, Valid Loss: 1.32879, Valid Acc: 0.68084,Valid Mean IU: 0.25787 ,Time: 0:0:35
# Epoch: 102, Train Loss: 0.94165, Train Acc: 0.78340, Train Mean IU: 0.28783, Valid Loss: 1.32391, Valid Acc: 0.68496,Valid Mean IU: 0.26311 ,Time: 0:0:36
# Epoch: 103, Train Loss: 0.93703, Train Acc: 0.78342, Train Mean IU: 0.29028, Valid Loss: 1.32820, Valid Acc: 0.67272,Valid Mean IU: 0.26379 ,Time: 0:0:35
# Epoch: 104, Train Loss: 0.92743, Train Acc: 0.78490, Train Mean IU: 0.29048, Valid Loss: 1.34994, Valid Acc: 0.67802,Valid Mean IU: 0.26388 ,Time: 0:0:35
# Epoch: 105, Train Loss: 0.92804, Train Acc: 0.78755, Train Mean IU: 0.29191, Valid Loss: 1.37608, Valid Acc: 0.67102,Valid Mean IU: 0.25261 ,Time: 0:0:34
# Epoch: 106, Train Loss: 0.93310, Train Acc: 0.78501, Train Mean IU: 0.28354, Valid Loss: 1.33798, Valid Acc: 0.69335,Valid Mean IU: 0.26044 ,Time: 0:0:35
# Epoch: 107, Train Loss: 0.92989, Train Acc: 0.78515, Train Mean IU: 0.28547, Valid Loss: 1.30046, Valid Acc: 0.69763,Valid Mean IU: 0.26809 ,Time: 0:0:36
# Epoch: 108, Train Loss: 0.93293, Train Acc: 0.78475, Train Mean IU: 0.28734, Valid Loss: 1.33496, Valid Acc: 0.66987,Valid Mean IU: 0.25288 ,Time: 0:0:34
# Epoch: 109, Train Loss: 0.91462, Train Acc: 0.78882, Train Mean IU: 0.29209, Valid Loss: 1.46029, Valid Acc: 0.65178,Valid Mean IU: 0.24441 ,Time: 0:0:36
# Epoch: 110, Train Loss: 0.91632, Train Acc: 0.78799, Train Mean IU: 0.29168, Valid Loss: 1.37448, Valid Acc: 0.69975,Valid Mean IU: 0.26223 ,Time: 0:0:36
# Epoch: 111, Train Loss: 0.90834, Train Acc: 0.79098, Train Mean IU: 0.29357, Valid Loss: 1.31384, Valid Acc: 0.70456,Valid Mean IU: 0.27038 ,Time: 0:0:36
# Epoch: 112, Train Loss: 0.91276, Train Acc: 0.78678, Train Mean IU: 0.29263, Valid Loss: 1.30043, Valid Acc: 0.70116,Valid Mean IU: 0.27632 ,Time: 0:0:36
# Epoch: 113, Train Loss: 0.91009, Train Acc: 0.78933, Train Mean IU: 0.29557, Valid Loss: 1.33413, Valid Acc: 0.68783,Valid Mean IU: 0.26240 ,Time: 0:0:36
# Epoch: 114, Train Loss: 0.89840, Train Acc: 0.79132, Train Mean IU: 0.29760, Valid Loss: 1.27642, Valid Acc: 0.69845,Valid Mean IU: 0.27753 ,Time: 0:0:36
# Epoch: 115, Train Loss: 0.89370, Train Acc: 0.79320, Train Mean IU: 0.29743, Valid Loss: 1.29235, Valid Acc: 0.68829,Valid Mean IU: 0.27704 ,Time: 0:0:35
# Epoch: 116, Train Loss: 0.89676, Train Acc: 0.79151, Train Mean IU: 0.29830, Valid Loss: 1.42229, Valid Acc: 0.69195,Valid Mean IU: 0.28693 ,Time: 0:0:34
# Epoch: 117, Train Loss: 0.89530, Train Acc: 0.79127, Train Mean IU: 0.29392, Valid Loss: 1.35984, Valid Acc: 0.69800,Valid Mean IU: 0.28262 ,Time: 0:0:34
# Epoch: 118, Train Loss: 0.88770, Train Acc: 0.79488, Train Mean IU: 0.29687, Valid Loss: 1.30085, Valid Acc: 0.69177,Valid Mean IU: 0.30607 ,Time: 0:0:34
# Epoch: 119, Train Loss: 0.89061, Train Acc: 0.79272, Train Mean IU: 0.29662, Valid Loss: 1.39386, Valid Acc: 0.68221,Valid Mean IU: 0.26502 ,Time: 0:0:36
# Epoch: 120, Train Loss: 0.88723, Train Acc: 0.79412, Train Mean IU: 0.30076, Valid Loss: 1.30010, Valid Acc: 0.68451,Valid Mean IU: 0.26984 ,Time: 0:0:36
# Epoch: 121, Train Loss: 0.89897, Train Acc: 0.79061, Train Mean IU: 0.29194, Valid Loss: 1.38955, Valid Acc: 0.68537,Valid Mean IU: 0.26492 ,Time: 0:0:35
# Epoch: 122, Train Loss: 0.88855, Train Acc: 0.79387, Train Mean IU: 0.29889, Valid Loss: 1.34467, Valid Acc: 0.66891,Valid Mean IU: 0.25891 ,Time: 0:0:36
# Epoch: 123, Train Loss: 0.87921, Train Acc: 0.79776, Train Mean IU: 0.30397, Valid Loss: 1.35919, Valid Acc: 0.67732,Valid Mean IU: 0.26700 ,Time: 0:0:36
# Epoch: 124, Train Loss: 0.87359, Train Acc: 0.79600, Train Mean IU: 0.30176, Valid Loss: 1.36545, Valid Acc: 0.71657,Valid Mean IU: 0.28969 ,Time: 0:0:36
# Epoch: 125, Train Loss: 0.86865, Train Acc: 0.79936, Train Mean IU: 0.30630, Valid Loss: 1.37121, Valid Acc: 0.67437,Valid Mean IU: 0.26922 ,Time: 0:0:36
# Epoch: 126, Train Loss: 0.86562, Train Acc: 0.79783, Train Mean IU: 0.30675, Valid Loss: 1.37378, Valid Acc: 0.69001,Valid Mean IU: 0.28298 ,Time: 0:0:35
# Epoch: 127, Train Loss: 0.85841, Train Acc: 0.80019, Train Mean IU: 0.30851, Valid Loss: 1.40601, Valid Acc: 0.69267,Valid Mean IU: 0.26538 ,Time: 0:0:35
# Epoch: 128, Train Loss: 0.86674, Train Acc: 0.79799, Train Mean IU: 0.30588, Valid Loss: 1.47702, Valid Acc: 0.65612,Valid Mean IU: 0.25599 ,Time: 0:0:35
# Epoch: 129, Train Loss: 0.86092, Train Acc: 0.80013, Train Mean IU: 0.30793, Valid Loss: 1.40595, Valid Acc: 0.68148,Valid Mean IU: 0.26036 ,Time: 0:0:36
# Epoch: 130, Train Loss: 0.85976, Train Acc: 0.79844, Train Mean IU: 0.30721, Valid Loss: 1.43136, Valid Acc: 0.67009,Valid Mean IU: 0.27314 ,Time: 0:0:34
# Epoch: 131, Train Loss: 0.86391, Train Acc: 0.79965, Train Mean IU: 0.30261, Valid Loss: 1.30992, Valid Acc: 0.68648,Valid Mean IU: 0.28059 ,Time: 0:0:35
# Epoch: 132, Train Loss: 0.84944, Train Acc: 0.80147, Train Mean IU: 0.31162, Valid Loss: 1.35109, Valid Acc: 0.67040,Valid Mean IU: 0.28485 ,Time: 0:0:35
# Epoch: 133, Train Loss: 0.85158, Train Acc: 0.80161, Train Mean IU: 0.31260, Valid Loss: 1.39146, Valid Acc: 0.68908,Valid Mean IU: 0.26034 ,Time: 0:0:36
# Epoch: 134, Train Loss: 0.84942, Train Acc: 0.80213, Train Mean IU: 0.31344, Valid Loss: 1.36836, Valid Acc: 0.67976,Valid Mean IU: 0.27615 ,Time: 0:0:35
# Epoch: 135, Train Loss: 0.84426, Train Acc: 0.80272, Train Mean IU: 0.31562, Valid Loss: 1.34588, Valid Acc: 0.67602,Valid Mean IU: 0.29762 ,Time: 0:0:36
# Epoch: 136, Train Loss: 0.86513, Train Acc: 0.79875, Train Mean IU: 0.30563, Valid Loss: 1.28370, Valid Acc: 0.69769,Valid Mean IU: 0.28658 ,Time: 0:0:36
# Epoch: 137, Train Loss: 0.84221, Train Acc: 0.80349, Train Mean IU: 0.30942, Valid Loss: 1.38074, Valid Acc: 0.68426,Valid Mean IU: 0.27009 ,Time: 0:0:35
# Epoch: 138, Train Loss: 0.88415, Train Acc: 0.79165, Train Mean IU: 0.30064, Valid Loss: 1.34608, Valid Acc: 0.68465,Valid Mean IU: 0.26005 ,Time: 0:0:36
# Epoch: 139, Train Loss: 0.85490, Train Acc: 0.79898, Train Mean IU: 0.30585, Valid Loss: 1.29025, Valid Acc: 0.69770,Valid Mean IU: 0.29072 ,Time: 0:0:35
# Epoch: 140, Train Loss: 0.85068, Train Acc: 0.80172, Train Mean IU: 0.31158, Valid Loss: 1.60103, Valid Acc: 0.63026,Valid Mean IU: 0.23458 ,Time: 0:0:35
# Epoch: 141, Train Loss: 0.83979, Train Acc: 0.80410, Train Mean IU: 0.31444, Valid Loss: 1.36020, Valid Acc: 0.66888,Valid Mean IU: 0.29115 ,Time: 0:0:36
# Epoch: 142, Train Loss: 0.83328, Train Acc: 0.80530, Train Mean IU: 0.31845, Valid Loss: 1.25211, Valid Acc: 0.69038,Valid Mean IU: 0.29103 ,Time: 0:0:36
# Epoch: 143, Train Loss: 0.81853, Train Acc: 0.80683, Train Mean IU: 0.31953, Valid Loss: 1.33565, Valid Acc: 0.69933,Valid Mean IU: 0.29085 ,Time: 0:0:35
# Epoch: 144, Train Loss: 0.83360, Train Acc: 0.80401, Train Mean IU: 0.31761, Valid Loss: 1.44975, Valid Acc: 0.68949,Valid Mean IU: 0.27292 ,Time: 0:0:35
# Epoch: 145, Train Loss: 0.82428, Train Acc: 0.80601, Train Mean IU: 0.32107, Valid Loss: 1.31665, Valid Acc: 0.70055,Valid Mean IU: 0.31778 ,Time: 0:0:35
# Epoch: 146, Train Loss: 0.82901, Train Acc: 0.80554, Train Mean IU: 0.31528, Valid Loss: 1.39956, Valid Acc: 0.68234,Valid Mean IU: 0.28853 ,Time: 0:0:35
# Epoch: 147, Train Loss: 0.81339, Train Acc: 0.80964, Train Mean IU: 0.32021, Valid Loss: 1.36991, Valid Acc: 0.70082,Valid Mean IU: 0.26739 ,Time: 0:0:35
# Epoch: 148, Train Loss: 0.82550, Train Acc: 0.80561, Train Mean IU: 0.31370, Valid Loss: 1.38928, Valid Acc: 0.69840,Valid Mean IU: 0.29783 ,Time: 0:0:35
# Epoch: 149, Train Loss: 0.81793, Train Acc: 0.80793, Train Mean IU: 0.31498, Valid Loss: 1.32562, Valid Acc: 0.70374,Valid Mean IU: 0.29230 ,Time: 0:0:35
# Epoch: 150, Train Loss: 0.81168, Train Acc: 0.80824, Train Mean IU: 0.31977, Valid Loss: 1.44343, Valid Acc: 0.70377,Valid Mean IU: 0.29190 ,Time: 0:0:36
# Epoch: 151, Train Loss: 0.81743, Train Acc: 0.80837, Train Mean IU: 0.31871, Valid Loss: 1.48802, Valid Acc: 0.67557,Valid Mean IU: 0.27474 ,Time: 0:0:35
# Epoch: 152, Train Loss: 0.81222, Train Acc: 0.81009, Train Mean IU: 0.32212, Valid Loss: 1.39958, Valid Acc: 0.68004,Valid Mean IU: 0.26730 ,Time: 0:0:36
# Epoch: 153, Train Loss: 0.80134, Train Acc: 0.81080, Train Mean IU: 0.32452, Valid Loss: 1.35235, Valid Acc: 0.69392,Valid Mean IU: 0.30055 ,Time: 0:0:35
# Epoch: 154, Train Loss: 0.80466, Train Acc: 0.81106, Train Mean IU: 0.32414, Valid Loss: 1.35626, Valid Acc: 0.69485,Valid Mean IU: 0.30821 ,Time: 0:0:35
# Epoch: 155, Train Loss: 0.80047, Train Acc: 0.81163, Train Mean IU: 0.32691, Valid Loss: 1.32617, Valid Acc: 0.69962,Valid Mean IU: 0.30063 ,Time: 0:0:34
# Epoch: 156, Train Loss: 0.80070, Train Acc: 0.81198, Train Mean IU: 0.32714, Valid Loss: 1.31729, Valid Acc: 0.69208,Valid Mean IU: 0.32628 ,Time: 0:0:35
# Epoch: 157, Train Loss: 0.80421, Train Acc: 0.81213, Train Mean IU: 0.32692, Valid Loss: 1.40001, Valid Acc: 0.69893,Valid Mean IU: 0.33838 ,Time: 0:0:35
# Epoch: 158, Train Loss: 0.80638, Train Acc: 0.81039, Train Mean IU: 0.32655, Valid Loss: 1.37539, Valid Acc: 0.67430,Valid Mean IU: 0.27913 ,Time: 0:0:34
# Epoch: 159, Train Loss: 0.79424, Train Acc: 0.81390, Train Mean IU: 0.32938, Valid Loss: 1.38110, Valid Acc: 0.70318,Valid Mean IU: 0.27948 ,Time: 0:0:35
# Epoch: 160, Train Loss: 0.79907, Train Acc: 0.81143, Train Mean IU: 0.32791, Valid Loss: 1.37361, Valid Acc: 0.68398,Valid Mean IU: 0.28464 ,Time: 0:0:35
# Epoch: 161, Train Loss: 0.79791, Train Acc: 0.80982, Train Mean IU: 0.32699, Valid Loss: 1.40826, Valid Acc: 0.70446,Valid Mean IU: 0.30412 ,Time: 0:0:36
# Epoch: 162, Train Loss: 0.78718, Train Acc: 0.81282, Train Mean IU: 0.32961, Valid Loss: 1.35240, Valid Acc: 0.69976,Valid Mean IU: 0.30840 ,Time: 0:0:35
# Epoch: 163, Train Loss: 0.78446, Train Acc: 0.81478, Train Mean IU: 0.33395, Valid Loss: 1.36962, Valid Acc: 0.71494,Valid Mean IU: 0.31963 ,Time: 0:0:35
# Epoch: 164, Train Loss: 0.78139, Train Acc: 0.81424, Train Mean IU: 0.33459, Valid Loss: 1.32094, Valid Acc: 0.69820,Valid Mean IU: 0.30877 ,Time: 0:0:36
# Epoch: 165, Train Loss: 0.79403, Train Acc: 0.81215, Train Mean IU: 0.33205, Valid Loss: 1.49469, Valid Acc: 0.68058,Valid Mean IU: 0.32418 ,Time: 0:0:36
# Epoch: 166, Train Loss: 0.79022, Train Acc: 0.81287, Train Mean IU: 0.33058, Valid Loss: 1.67951, Valid Acc: 0.62076,Valid Mean IU: 0.22248 ,Time: 0:0:34
# Epoch: 167, Train Loss: 0.81775, Train Acc: 0.80863, Train Mean IU: 0.31850, Valid Loss: 1.30581, Valid Acc: 0.70074,Valid Mean IU: 0.29723 ,Time: 0:0:36
# Epoch: 168, Train Loss: 0.79826, Train Acc: 0.81195, Train Mean IU: 0.32079, Valid Loss: 1.41035, Valid Acc: 0.70547,Valid Mean IU: 0.31194 ,Time: 0:0:35
# Epoch: 169, Train Loss: 0.77555, Train Acc: 0.81607, Train Mean IU: 0.32973, Valid Loss: 1.38161, Valid Acc: 0.71146,Valid Mean IU: 0.29293 ,Time: 0:0:35
# Epoch: 170, Train Loss: 0.78239, Train Acc: 0.81519, Train Mean IU: 0.33474, Valid Loss: 1.44385, Valid Acc: 0.68693,Valid Mean IU: 0.30940 ,Time: 0:0:34
# Epoch: 171, Train Loss: 0.77381, Train Acc: 0.81662, Train Mean IU: 0.33878, Valid Loss: 1.34507, Valid Acc: 0.70174,Valid Mean IU: 0.32540 ,Time: 0:0:35
# Epoch: 172, Train Loss: 0.77075, Train Acc: 0.81710, Train Mean IU: 0.33988, Valid Loss: 1.38103, Valid Acc: 0.70823,Valid Mean IU: 0.34003 ,Time: 0:0:35
# Epoch: 173, Train Loss: 0.77507, Train Acc: 0.81655, Train Mean IU: 0.33681, Valid Loss: 1.31364, Valid Acc: 0.68721,Valid Mean IU: 0.30486 ,Time: 0:0:35
# Epoch: 174, Train Loss: 0.80741, Train Acc: 0.80868, Train Mean IU: 0.32110, Valid Loss: 1.43080, Valid Acc: 0.71664,Valid Mean IU: 0.29621 ,Time: 0:0:35
# Epoch: 175, Train Loss: 0.79198, Train Acc: 0.81400, Train Mean IU: 0.32543, Valid Loss: 1.43027, Valid Acc: 0.70165,Valid Mean IU: 0.30265 ,Time: 0:0:35
# Epoch: 176, Train Loss: 0.76932, Train Acc: 0.81833, Train Mean IU: 0.34046, Valid Loss: 1.42150, Valid Acc: 0.70057,Valid Mean IU: 0.29665 ,Time: 0:0:35
# Epoch: 177, Train Loss: 0.76646, Train Acc: 0.81883, Train Mean IU: 0.34243, Valid Loss: 1.42979, Valid Acc: 0.70296,Valid Mean IU: 0.30581 ,Time: 0:0:36
# Epoch: 178, Train Loss: 0.76109, Train Acc: 0.81920, Train Mean IU: 0.34527, Valid Loss: 1.41995, Valid Acc: 0.70571,Valid Mean IU: 0.29642 ,Time: 0:0:36
# Epoch: 179, Train Loss: 0.76092, Train Acc: 0.81920, Train Mean IU: 0.34226, Valid Loss: 1.47009, Valid Acc: 0.69646,Valid Mean IU: 0.32166 ,Time: 0:0:35
# Epoch: 180, Train Loss: 0.76143, Train Acc: 0.81940, Train Mean IU: 0.33973, Valid Loss: 1.39504, Valid Acc: 0.70027,Valid Mean IU: 0.29385 ,Time: 0:0:35
# Epoch: 181, Train Loss: 0.75808, Train Acc: 0.81888, Train Mean IU: 0.34188, Valid Loss: 1.41459, Valid Acc: 0.71475,Valid Mean IU: 0.32652 ,Time: 0:0:35
# Epoch: 182, Train Loss: 0.76145, Train Acc: 0.81973, Train Mean IU: 0.34372, Valid Loss: 1.45936, Valid Acc: 0.69347,Valid Mean IU: 0.30462 ,Time: 0:0:36
# Epoch: 183, Train Loss: 0.75501, Train Acc: 0.82045, Train Mean IU: 0.34382, Valid Loss: 1.37635, Valid Acc: 0.71657,Valid Mean IU: 0.33997 ,Time: 0:0:36
# Epoch: 184, Train Loss: 0.76485, Train Acc: 0.81859, Train Mean IU: 0.34498, Valid Loss: 1.38847, Valid Acc: 0.70855,Valid Mean IU: 0.31076 ,Time: 0:0:35
# Epoch: 185, Train Loss: 0.75932, Train Acc: 0.81995, Train Mean IU: 0.34131, Valid Loss: 1.36265, Valid Acc: 0.70141,Valid Mean IU: 0.31335 ,Time: 0:0:36
# Epoch: 186, Train Loss: 0.74958, Train Acc: 0.82165, Train Mean IU: 0.34661, Valid Loss: 1.40404, Valid Acc: 0.70053,Valid Mean IU: 0.29890 ,Time: 0:0:35
# Epoch: 187, Train Loss: 0.75056, Train Acc: 0.82130, Train Mean IU: 0.34638, Valid Loss: 1.45834, Valid Acc: 0.70326,Valid Mean IU: 0.32406 ,Time: 0:0:36
# Epoch: 188, Train Loss: 0.75627, Train Acc: 0.81988, Train Mean IU: 0.34684, Valid Loss: 1.36970, Valid Acc: 0.70122,Valid Mean IU: 0.31792 ,Time: 0:0:35
# Epoch: 189, Train Loss: 0.74795, Train Acc: 0.82179, Train Mean IU: 0.34914, Valid Loss: 1.43016, Valid Acc: 0.71522,Valid Mean IU: 0.32283 ,Time: 0:0:35
# Epoch: 190, Train Loss: 0.75325, Train Acc: 0.82180, Train Mean IU: 0.34589, Valid Loss: 1.37357, Valid Acc: 0.71291,Valid Mean IU: 0.33289 ,Time: 0:0:35
# Epoch: 191, Train Loss: 0.74569, Train Acc: 0.82197, Train Mean IU: 0.35169, Valid Loss: 1.41240, Valid Acc: 0.69630,Valid Mean IU: 0.31558 ,Time: 0:0:35
# Epoch: 192, Train Loss: 0.74735, Train Acc: 0.82281, Train Mean IU: 0.35030, Valid Loss: 1.41073, Valid Acc: 0.70777,Valid Mean IU: 0.34537 ,Time: 0:0:35
# Epoch: 193, Train Loss: 0.73910, Train Acc: 0.82298, Train Mean IU: 0.34840, Valid Loss: 1.40266, Valid Acc: 0.71571,Valid Mean IU: 0.35561 ,Time: 0:0:35
# Epoch: 194, Train Loss: 0.73471, Train Acc: 0.82344, Train Mean IU: 0.35412, Valid Loss: 1.42519, Valid Acc: 0.71688,Valid Mean IU: 0.30878 ,Time: 0:0:36
# Epoch: 195, Train Loss: 0.73151, Train Acc: 0.82416, Train Mean IU: 0.35314, Valid Loss: 1.40119, Valid Acc: 0.70831,Valid Mean IU: 0.30715 ,Time: 0:0:36
# Epoch: 196, Train Loss: 0.73689, Train Acc: 0.82430, Train Mean IU: 0.35456, Valid Loss: 1.38781, Valid Acc: 0.70889,Valid Mean IU: 0.31795 ,Time: 0:0:35
# Epoch: 197, Train Loss: 0.73958, Train Acc: 0.82263, Train Mean IU: 0.34895, Valid Loss: 1.41743, Valid Acc: 0.71222,Valid Mean IU: 0.32759 ,Time: 0:0:36
# Epoch: 198, Train Loss: 0.73509, Train Acc: 0.82418, Train Mean IU: 0.35283, Valid Loss: 1.48910, Valid Acc: 0.70743,Valid Mean IU: 0.31584 ,Time: 0:0:36
# Epoch: 199, Train Loss: 0.73424, Train Acc: 0.82463, Train Mean IU: 0.35612, Valid Loss: 1.39340, Valid Acc: 0.70623,Valid Mean IU: 0.33551 ,Time: 0:0:36

# %%
import pandas as pd

data = {"train_loss":train_loss,"eval_loss":eval_loss,"train_acc":train_acc,"eval_acc":eval_acc,"train_miou":train_mean_iu,"eval_miou":eval_mean_iu}
result = pd.DataFrame(data)
result.to_csv("result_aug_batch5_lr0.001_drop.csv",index=False)

# %%
def predict(img, label): # 预测结果
    img = Variable(img.unsqueeze(0)).cuda()
    out = net(img)
    pred = out.max(1)[1].squeeze().cpu().data.numpy()
    return pred, label
# 显示当前网络的训练结果
def show(size=224, num_image=4, img_size=10, offset=0, shuffle=False):
    _, figs = plt.subplots(num_image, 3, figsize=(img_size, img_size))
    for i in range(num_image):
        if(shuffle==True):
            offset = rand.randint(0, min(len(camvid_train)-i-1, len(camvid_test)-i-1))
        img_data, img_label = camvid_test[i+offset]
        pred, label = predict(img_data, img_label)
        img_data = Image.open(camvid_test.data_list[i+offset])
        img_label = Image.open(camvid_test.label_list[i+offset])
        img_data, img_label = crop(img_data, img_label)
        figs[i, 0].imshow(img_data)  # 原始图片
        figs[i, 0].axes.get_xaxis().set_visible(False)  # 去掉x轴
        figs[i, 0].axes.get_yaxis().set_visible(False)  # 去掉y轴
        figs[i, 1].imshow(img_label)                    # 标签
        figs[i, 1].axes.get_xaxis().set_visible(False)  # 去掉x轴
        figs[i, 1].axes.get_yaxis().set_visible(False)  # 去掉y轴
        figs[i, 2].imshow(pred)                         # 模型输出结果
        figs[i, 2].axes.get_xaxis().set_visible(False)  # 去掉x轴
        figs[i, 2].axes.get_yaxis().set_visible(False)  # 去掉y轴

    # 在最后一行图片下面添加标题
    figs[num_image-1, 0].set_title("Image", y=-0.2*(10/img_size))
    figs[num_image-1, 1].set_title("Label", y=-0.2*(10/img_size))
    figs[num_image-1, 2].set_title("segnet", y=-0.2*(10/img_size))
    plt.show()
